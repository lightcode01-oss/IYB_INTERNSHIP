# %% [markdown]
# <a href="https://colab.research.google.com/github/lightcode01-oss/IYB_INTERNSHIP/blob/main/YBI_45_Days_Student_Performance_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI-Based Student Performance Prediction System
#
# ## YBI Foundation — Python, AI & Data Science Internship
#
# ### Project Overview
#
# This project focuses on analyzing student-related academic and behavioral
# data and developing a machine learning model for predicting student
# performance.
#
# The project follows an end-to-end Data Science and Machine Learning
# workflow, beginning with problem understanding and data collection and
# continuing through data preprocessing, exploratory data analysis,
# feature engineering, model development, evaluation, and prediction.
#
# ### Project Objectives
#
# - Understand the factors associated with student performance.
# - Clean and preprocess the dataset.
# - Perform exploratory data analysis.
# - Visualize important patterns in the data.
# - Prepare suitable features for machine learning.
# - Train multiple machine learning models.
# - Compare model performance using appropriate evaluation metrics.
# - Select and evaluate a final model.
# - Build a simple prediction system.
#
# ### Technology Stack
#
# - Python
# - Google Colab
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
#
# ### Machine Learning Approach
#
# This project will use supervised machine learning techniques for
# classification.
#
# ### Project Duration
#
# 45 Days

# %% [markdown]
# # DAY 01 — Project Initialization
#
# ## Problem Understanding
#
# Student performance is influenced by several measurable academic and
# behavioral factors. Understanding these factors can help identify patterns
# in student outcomes and support data-driven analysis.
#
# The objective of this project is to develop a machine learning based system
# that can learn from historical student data and predict the performance
# category of a student.
#
# ## Initial Workflow
#
# The project will follow these stages:
#
# 1. Problem Definition
# 2. Dataset Research and Collection
# 3. Data Understanding
# 4. Data Cleaning
# 5. Exploratory Data Analysis
# 6. Feature Engineering
# 7. Data Preparation
# 8. Machine Learning Model Development
# 9. Model Evaluation
# 10. Model Comparison
# 11. Final Model Selection
# 12. Prediction System
# 13. Documentation and Final Review

# %%
# DAY 01
# Importing the basic libraries required for the project

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Python environment initialized successfully.")
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
# Out:
# Python environment initialized successfully.
# NumPy version: 2.1.3
# Pandas version: 2.2.3

# %%
# Basic project information

project_info = {
    "Project Title": "AI-Based Student Performance Prediction System",
    "Domain": "Artificial Intelligence & Data Science",
    "Programming Language": "Python",
    "Platform": "Google Colab",
    "Learning Type": "Supervised Learning",
    "Problem Type": "Classification",
    "Project Duration": "45 Days"
}

project_info
# Out:
# {'Project Title': 'AI-Based Student Performance Prediction System',
#  'Domain': 'Artificial Intelligence & Data Science',
#  'Programming Language': 'Python',
#  'Platform': 'Google Colab',
#  'Learning Type': 'Supervised Learning',
#  'Problem Type': 'Classification',
#  'Project Duration': '45 Days'}

# %%
# Checking the availability of Scikit-learn

import sklearn

print("Scikit-learn version:", sklearn.__version__)
print("Machine Learning environment is ready.")
# Out:
# Scikit-learn version: 1.6.1
# Machine Learning environment is ready.

# %% [markdown]
# ## Day 01 Development Log
#
# ### Work Completed
#
# - Defined the project problem.
# - Defined the initial project objectives.
# - Identified the project as a supervised learning classification problem.
# - Initialized the Google Colab environment.
# - Imported the required Python libraries.
# - Verified the machine learning environment.
#
# ### Next Step
#
# Day 02 will focus on researching and selecting a suitable dataset for the
# project.

# %%
print("=" * 50)
print("YBI INTERNSHIP — DAY 01")
print("=" * 50)
print("Project : AI-Based Student Performance Prediction System")
print("Status  : Day 01 Completed")
print("=" * 50)
# Out:
# ...
# YBI INTERNSHIP — DAY 01
# ...
# Project : AI-Based Student Performance Prediction System
# Status  : Day 01 Completed
# ...
